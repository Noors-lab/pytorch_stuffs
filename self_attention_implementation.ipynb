# %% [markdown]
# <a href="https://colab.research.google.com/github/Noors-lab/pytorch_stuffs/blob/main/self_attention_implementation_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # the libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# create a class
class self_attention(nn.Module):
  def __init__(self,embed_dim):
    super().__init__()
    self.embed_dim = embed_dim
    self.d_k = embed_dim ** 0.5


    self.query = nn.Linear(embed_dim,embed_dim)
    self.key = nn.Linear(embed_dim,embed_dim)
    self.value = nn.Linear(embed_dim,embed_dim)

# create forward function
  def forward(self,x):
    Q = self.query(x)
    K = self.key(x)
    V = self.value(x)

# compute attention score
    score = torch.matmul(Q,K.transpose(-2,-1))/self.d_k
    attention = F.softmax(score,dim=-1)

# weighted sum of value
    output = torch.matmul(attention,V)
    return output,attention


# example
batch_size = 1
seq_len = 6
embed_dim = 8

x = torch.randn(batch_size,seq_len,embed_dim)

attn = self_attention(embed_dim)
output,attention_score = attn(x)
print(f"output shape: {output.shape}")
print(f"attention score: {attention_score}")
# Out:
# output shape: torch.Size([1, 6, 8])
# attention score: tensor([[[0.1413, 0.1462, 0.1580, 0.1762, 0.1855, 0.1928],
#          [0.1574, 0.3278, 0.0711, 0.0441, 0.2217, 0.1778],
#          [0.1238, 0.0860, 0.1967, 0.2895, 0.1513, 0.1527],
#          [0.1359, 0.0933, 0.1828, 0.3021, 0.1320, 0.1539],
#          [0.1753, 0.2434, 0.1266, 0.0976, 0.1951, 0.1619],
#          [0.1747, 0.1495, 0.1711, 0.1792, 0.1700, 0.1556]]],
#        grad_fn=<SoftmaxBackward0>)
